# %% [markdown]
# ##lambda

# %%
square = lambda x:x*x
print(square(5))
# Out:
# 25

# %%
# lambda arguments:expression
# for example:- lambda x: x + 10

# multiple arguments

add = lambda x,y: x+y
print (10,20)
# Out:
# 10 20

# %%
multiply = lambda x,y: x*y
print(multiply(5,4))
# Out:
# 20
