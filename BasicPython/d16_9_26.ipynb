# %% [markdown]
# ##Comprehensions

# %%
squares = []
for x in range(1,6):
    squares.append(x**2)
    
print(squares)
#can be written as 

squares = [x**2 for x in range(1,6)]
print(squares)
# Out:
# [1, 4, 9, 16, 25]
# [1, 4, 9, 16, 25]

# %% [markdown]
# ##[expression for item in iterable]
